# %% [markdown]
# # This is a sample Jupyter Notebook
#
# Below is an example of a code cell.
# Put your cursor into the cell and press Shift+Enter to execute it and select the next one, or click 'Run Cell' button.
#
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.
#
# To learn more about Jupyter Notebooks in PyCharm, see [help](https://www.jetbrains.com/help/pycharm/ipython-notebook-support.html).
# For an overview of PyCharm, go to Help -> Learn IDE features or refer to [our documentation](https://www.jetbrains.com/help/pycharm/getting-started.html).

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
expr = input().strip()
expr = input().strip()

# Dozwolone znaki
allowed = set("0123456789+-*/ ")

# Sprawdzenie poprawności znaków
for ch in expr:
    if ch not in allowed:
        print("Błąd: niedozwolony znak:", ch)
        exit()

# Usunięcie zbędnych spacji
expr = expr.replace(" ", "")

# Rozdzielenie na pierwszą część (liczby/operatory)
ops = []
nums = []
current = ""

for ch in expr:
    if ch.isdigit():
        current += ch
    else:
        nums.append(float(current))
        current = ""
        ops.append(ch)

nums.append(float(current))

# Teraz mamy np. nums = [3, 4, 7], ops = ['+', '*']

# Najpierw * i /
i = 0
while i < len(ops):
    if ops[i] == '*' or ops[i] == '/':
        if ops[i] == '*':
            nums[i] = nums[i] * nums[i+1]
        else:
            nums[i] = nums[i] / nums[i+1]
        del nums[i+1]
        del ops[i]
    else:
        i += 1

# Teraz + i -
result = nums[0]
for i in range(len(ops)):
    if ops[i] == '+':
        result += nums[i+1]
    else:
        result -= nums[i+1]

print(result)

# Dozwolone znaki
allowed = set("0123456789+-*/ ")

# Sprawdzenie poprawności znaków
for ch in expr:
    if ch not in allowed:
        print("Błąd: niedozwolony znak:", ch)
        exit()

# Usunięcie zbędnych spacji
expr = expr.replace(" ", "")

# Rozdzielenie na pierwszą część (liczby/operatory)
ops = []
nums = []
current = ""

for ch in expr:
    if ch.isdigit():
        current += ch
    else:
        nums.append(float(current))
        current = ""
        ops.append(ch)

nums.append(float(current))

# Teraz mamy np. nums = [3, 4, 7], ops = ['+', '*']

# Najpierw * i /
i = 0
while i < len(ops):
    if ops[i] == '*' or ops[i] == '/':
        if ops[i] == '*':
            nums[i] = nums[i] * nums[i+1]
        else:
            nums[i] = nums[i] / nums[i+1]
        del nums[i+1]
        del ops[i]
    else:
        i += 1

# Teraz + i -
result = nums[0]
for i in range(len(ops)):
    if ops[i] == '+':
        result += nums[i+1]
    else:
        result -= nums[i+1]

print(result)
# Out:
# 31.0
# 31.0
